# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv("Obesity - Obesity.csv")

# Plotting some interesting visualizations
Obesity - Obesity.csv
# 1. Distribution of Age
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='Age', bins=30, kde=True, hue='NObeyesdad', multiple="stack")
plt.title('Distribution of Age by Obesity Level')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# 4. Boxplot to visualize the distribution of Weight by Gender
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Gender', y='Weight', hue='NObeyesdad')
plt.title('Distribution of Weight by Gender and Obesity Level')
plt.xlabel('Gender')
plt.ylabel('Weight')
plt.legend(title='Obesity Level')
plt.show()

# 5. Bar plot to visualize the average number of main meals (NCP) by Obesity Level
plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='NObeyesdad', y='NCP', estimator=lambda x: sum(x) / len(x))
plt.title('Average Number of Main Meals by Obesity Level')
plt.xlabel('Obesity Level')
plt.ylabel('Average Number of Main Meals')
plt.show()

# 6. Heatmap to visualize the correlation between numeric features
plt.figure(figsize=(10, 8))
sns.heatmap(data[numeric_features].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# 7. Swarmplot to visualize the relationship between Age and Physical Activity Frequency (FAF) by Gender
plt.figure(figsize=(10, 6))
sns.swarmplot(data=data, x='Gender', y='FAF', hue='NObeyesdad')
plt.title('Relationship between Age and Physical Activity Frequency by Gender and Obesity Level')
plt.xlabel('Gender')
plt.ylabel('Physical Activity Frequency')
plt.legend(title='Obesity Level')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 20
#      18 # 6. Heatmap to visualize the correlation between numeric features
#      19 plt.figure(figsize=(10, 8))
# ---> 20 sns.heatmap(data[numeric_features].corr(), annot=True, cmap='coolwarm', fmt=".2f")
#      21 plt.title('Correlation Heatmap of Numeric Features')
#      22 plt.show()
#
# NameError: name 'numeric_features' is not defined

# %%
categorical_features = ['family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']
plt.figure(figsize=(14, 8))
for i, feature in enumerate(categorical_features, 1):
    plt.subplot(2, 4, i)
    sns.countplot(data=data, x=feature, hue='NObeyesdad')
    plt.title(f'Countplot of {feature} by Obesity Level')
    plt.xlabel(feature)
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group by 'family_history_with_overweight' and 'NObeyesdad', calculate counts, and transform to percentages
percentage_data = data.groupby(['family_history_with_overweight', 'NObeyesdad']).size().reset_index(name='count')
percentage_data['percentage'] = percentage_data.groupby('family_history_with_overweight')['count'].transform(lambda x: x / x.sum() * 100)

# Plot
plt.figure(figsize=(8, 6))
sns.barplot(data=percentage_data, x='family_history_with_overweight', y='percentage', hue='NObeyesdad', palette='Set1')
plt.title('Percentage of Obesity Levels by Family History with Overweight')
plt.xlabel('Family History with Overweight')
plt.ylabel('Percentage')
plt.legend(title='Obesity Level')
plt.show()

# %%
data['NObeyesdad']
# Out:
# 0             Normal_Weight
# 1             Normal_Weight
# 2             Normal_Weight
# 3        Overweight_Level_I
# 4       Overweight_Level_II
#                ...
# 2106       Obesity_Type_III
# 2107       Obesity_Type_III
# 2108       Obesity_Type_III
# 2109       Obesity_Type_III
# 2110       Obesity_Type_III
# Name: NObeyesdad, Length: 2111, dtype: object

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(data=data, x='Gender', y='FAF', hue='NObeyesdad')
plt.title('Relationship between Age and Physical Activity Frequency by Gender and Obesity Level')
plt.xlabel('Gender')
plt.ylabel('Physical Activity Frequency')
plt.legend(title='Obesity Level')
plt.show()
# Out:
# C:\Users\gaura\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 25.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gaura\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 23.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gaura\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 35.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gaura\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 34.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(15, 6))
sns.barplot(data=data, x='NObeyesdad', y='NCP', estimator=lambda x: sum(x) / len(x))
plt.title('Average Number of Main Meals by Obesity Level')
plt.xlabel('Obesity Level')
plt.ylabel('Average Number of Main Meals')
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.barplot(data=data, x='NObeyesdad', y='TUE', estimator=lambda x: sum(x) / len(x))
plt.title('Average Time Spent Using Technological Devices by Obesity Level')
plt.xlabel('Obesity Level')
plt.ylabel('Average Time Spent (in hours)')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of Age by Obesity Level
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='NObeyesdad', y='Age')
plt.title('Distribution of Age by Obesity Level')
plt.xlabel('Obesity Level')
plt.ylabel('Age')
plt.show()

# Violin Plot of Height and Weight by Gender
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='Gender', y='Height', palette='Set1', inner='quartile')
plt.title('Distribution of Height by Gender')
plt.xlabel('Gender')
plt.ylabel('Height')
plt.show()

plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='Gender', y='Weight', palette='Set2', inner='quartile')
plt.title('Distribution of Weight by Gender')
plt.xlabel('Gender')
plt.ylabel('Weight')
plt.show()

# Barplot of Frequency of High-Caloric Food Consumption by Obesity Level and Gender
plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='NObeyesdad', y='FAVC', hue='Gender', palette='Set1')
plt.title('Frequency of High-Caloric Food Consumption by Obesity Level and Gender')
plt.xlabel('Obesity Level')
plt.ylabel('Frequency of High-Caloric Food Consumption')
plt.legend(title='Gender')
plt.show()

# Pairplot of Numeric Features by Obesity Level
numeric_features = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']
sns.pairplot(data=data, vars=numeric_features, hue='NObeyesdad')
plt.suptitle('Pairplot of Numeric Features by Obesity Level')
plt.show()

# Countplot of Smoking Status by Obesity Level
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='NObeyesdad', hue='SMOKE', palette='Set1')
plt.title('Smoking Status by Obesity Level')
plt.xlabel('Obesity Level')
plt.ylabel('Count')
plt.legend(title='Smoking Status')
plt.show()

# Heatmap of Correlation Matrix
correlation_matrix = data[numeric_features].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Numeric Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 29
#      27 # Barplot of Frequency of High-Caloric Food Consumption by Obesity Level and Gender
#      28 plt.figure(figsize=(10, 6))
# ---> 29 sns.barplot(data=data, x='NObeyesdad', y='FAVC', hue='Gender', palette='Set1')
#      30 plt.title('Frequency of High-Caloric Food Consumption by Obesity Level and Gender')
#      31 plt.xlabel('Obesity Level')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
# ...

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='Gender', y='Height', palette='Set1', inner='quartile')
plt.title('Distribution of Height by Gender')
plt.xlabel('Gender')
plt.ylabel('Height')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import balanced_accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import balanced_accuracy_score

# %%
obesity=pd.read_csv('Obesity - Obesity.csv')
obesity
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
#Split the data into Independent and Dependent Variable
x_obesity=obesity.iloc[:, :-1]
y_obesity=obesity['NObeyesdad']

# %%
#Split the data into train and test
x_train, x_test, y_train, y_test = train_test_split(x_obesity, y_obesity, test_size=0.2, random_state=22212311)

# %%
#Divide the columns among categorical and numerical data types
numerical=list()
categorical=list()
for i in cardiac.columns:
    if cardiac[i].dtype == 'object':
        categorical.append(i)
    else:
        numerical.append(i)

# %%
categorical.pop()
categorical
# Out:
# ['Gender',
#  'family_history_with_overweight',
#  'FAVC',
#  'CAEC',
#  'SMOKE',
#  'SCC',
#  'CALC',
#  'MTRANS']

# %%
numerical
# Out:
# ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

# %%
#Convert the categorical data into numerical data by label encoding
label_encoder = preprocessing.LabelEncoder()
for i in categorical:
    x_train[i]= label_encoder.fit_transform(x_train[i])
    x_test[i]= label_encoder.fit_transform(x_test[i])

# %%
#Standardized/normalised the data by min max scaler so all values lies between 0 to 1
min_max= MinMaxScaler()
min_max_train = min_max.fit_transform(x_train)
min_max_test = min_max.fit_transform(x_test)
x_train = pd.DataFrame(min_max_train, columns=x_train.columns, index=x_train.index)
x_test = pd.DataFrame(min_max_test, columns=x_test.columns, index=x_test.index)

# %%
#getting all the columns having value correlation greater than 0.8
matrix = x_train.corr()
col = [matrix.columns[i] for i in range(len(matrix.columns)) for j in range(i) if abs(matrix.iloc[i, j]) >= 0.8]
col
# Out:
# []

# %%
#Calculating the VIF of each columns to check multicollinearity
variance_inflance_factor = pd.DataFrame()
variance_inflance_factor['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
variance_inflance_factor['variable'] = x_train.columns
variance_inflance_factor
# Out:
#           VIF                        variable
# 0    3.921022                          Gender
# 1    4.788913                             Age
# 2   20.635538                          Height
# 3    9.023968                          Weight
# 4    8.035267  family_history_with_overweight
# 5    9.497588                            FAVC
# 6    8.756746                            FCVC
# 7    5.731388                             NCP
# 8   16.079692                            CAEC
# 9    1.066120                           SMOKE
# 10   4.190588                            CH2O
# 11   1.121669                             SCC
# 12   3.004596                             FAF
# 13   2.427098                             TUE
# 14  16.133539                            CALC
# 15   6.036212                          MTRANS

# %%
#Use the sklearn library of Logistic Regression
logistic_model = LogisticRegression()

# Fit the model
logistic_model.fit(x_train, y_train)

# Make predictions
y_pred = logistic_model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
# Out:
# C:\Users\gaura\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy
# Out:
# 0.6690307328605201

# %%
balanced_accuracy_score(y_test,y_pred)
# Out:
# 0.681641760477776

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot()

# %%
print(classification_rep)
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.77      0.81      0.79        53
#       Normal_Weight       0.64      0.44      0.52        68
#      Obesity_Type_I       0.62      0.49      0.55        68
#     Obesity_Type_II       0.63      1.00      0.78        59
#    Obesity_Type_III       0.90      1.00      0.94        60
#  Overweight_Level_I       0.49      0.63      0.55        51
# Overweight_Level_II       0.62      0.41      0.49        64
#
#            accuracy                           0.67       423
#           macro avg       0.67      0.68      0.66       423
#        weighted avg       0.67      0.67      0.65       423

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the Random Forest classifier
rf_classifier.fit(x_train, y_train)

# Make predictions on the test set
y_pred = rf_classifier.predict(x_test)
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8605200945626478

# %%
balanced_accuracy_score(y_test,y_pred)
# Out:
# 0.8600604156757042

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot()

# %%
print(classification_rep)
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.98      0.92      0.95        53
#       Normal_Weight       0.88      0.90      0.89        68
#      Obesity_Type_I       0.79      0.74      0.76        68
#     Obesity_Type_II       0.78      1.00      0.87        59
#    Obesity_Type_III       1.00      1.00      1.00        60
#  Overweight_Level_I       0.89      0.67      0.76        51
# Overweight_Level_II       0.76      0.80      0.78        64
#
#            accuracy                           0.86       423
#           macro avg       0.87      0.86      0.86       423
#        weighted avg       0.87      0.86      0.86       423

# %%
roc_auc = roc_auc_score(y_test, y_pred)
print("ROC AUC:", roc_auc)

# ROC Curve (Optional)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'r--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 roc_auc = roc_auc_score(y_test, y_pred)
#       2 print("ROC AUC:", roc_auc)
#       4 # ROC Curve (Optional)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
# ...

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=3)

# Train the KNN classifier
knn_classifier.fit(x_train, y_train)

# Make predictions on the test set
y_pred = knn_classifier.predict(x_test)
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 0.7966903073286052

# %%
balanced_accuracy_score(y_test,y_pred)
# Out:
# 0.8014597968224707

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot()

# %%
print(classification_rep)
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.69      0.91      0.78        53
#       Normal_Weight       0.69      0.46      0.55        68
#      Obesity_Type_I       0.82      0.85      0.83        68
#     Obesity_Type_II       0.83      0.98      0.90        59
#    Obesity_Type_III       0.97      1.00      0.98        60
#  Overweight_Level_I       0.75      0.65      0.69        51
# Overweight_Level_II       0.80      0.77      0.78        64
#
#            accuracy                           0.80       423
#           macro avg       0.79      0.80      0.79       423
#        weighted avg       0.79      0.80      0.79       423

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)

# Train the Decision Tree classifier
dt_classifier.fit(x_train, y_train)

# Make predictions on the test set
y_pred = dt_classifier.predict(x_test)
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 0.7470449172576832

# %%
balanced_accuracy_score(y_test,y_pred)
# Out:
# 0.7502147085249194

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot()

# %%
print(classification_rep)
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.92      0.87      0.89        53
#       Normal_Weight       0.82      0.66      0.73        68
#      Obesity_Type_I       0.64      0.54      0.59        68
#     Obesity_Type_II       0.68      1.00      0.81        59
#    Obesity_Type_III       1.00      1.00      1.00        60
#  Overweight_Level_I       0.62      0.49      0.55        51
# Overweight_Level_II       0.60      0.69      0.64        64
#
#            accuracy                           0.75       423
#           macro avg       0.75      0.75      0.74       423
#        weighted avg       0.75      0.75      0.74       423

# %%
svm_classifier = SVC(kernel='linear', random_state=42)

# Train the SVM classifier
svm_classifier.fit(x_train, y_train)

# Make predictions on the test set
y_pred = svm_classifier.predict(x_test)
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 0.7683215130023641

# %%
balanced_accuracy_score(y_test,y_pred)
# Out:
# 0.7788171872522593

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot()

# %%
print(classification_rep)
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.88      0.98      0.93        53
#       Normal_Weight       0.90      0.65      0.75        68
#      Obesity_Type_I       0.71      0.62      0.66        68
#     Obesity_Type_II       0.68      1.00      0.81        59
#    Obesity_Type_III       1.00      1.00      1.00        60
#  Overweight_Level_I       0.59      0.71      0.64        51
# Overweight_Level_II       0.67      0.50      0.57        64
#
#            accuracy                           0.77       423
#           macro avg       0.78      0.78      0.77       423
#        weighted avg       0.78      0.77      0.76       423
